# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=[16, 16])
for i in range(1,8):
    dataset.append(plt.imread("ostDataset/{}.jpg".format(i)))
    plt.subplot(int("18{}".format(i)))
    plt.imshow(dataset[i])
